# %%
'''
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))['data']
docs[:5]

print('total num doc: ', len(docs))
'''

def get_data(path, y):

	texts = []
	labels = []

	with open(path, encoding='utf-8') as f:
		for line in f:
			line = line.strip()
			texts.append(line)
			labels.append(y)

	return texts, labels

# load data
paths = ['../data/train.negative.csv',
			'../data/train.non-negative.csv',
			'../data/test.negative.csv',
			'../data/test.non-negative.csv']

# get data as list of dict with text and label
train_neg_x_ls, train_neg_y_ls = get_data(paths[0], 1)
train_non_x_ls, train_non_y_ls = get_data(paths[1], 0)
test_neg_x_ls, test_neg_y_ls = get_data(paths[2], 1)
test_non_x_ls, test_non_y_ls = get_data(paths[3], 0)

train_data = train_neg_x_ls + train_non_x_ls
test_data = test_neg_x_ls + test_non_x_ls

print('train data length: ', len(train_data))

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
train_data = [ [word for word in sentence.strip().split() if not word in stop_words and word != ' '] for sentence in train_data]

train_data = [' '.join(sentence) for sentence in train_data]
print(len(train_data))
# Out:
# train data length:  14643
# 14643

# %%
print(train_data[1])
# Out:
# That third time I called 800-433-7300 hung anyone speaks. What I now???

# %%
from bertopic import BERTopic

model = BERTopic(nr_topics='auto')
topics, probabilities = model.fit_transform(train_data)

print(model.get_topic(5))
# Out:
# [('customer', 0.05198314710627725), ('service', 0.04641739241846186), ('customers', 0.03651634940694557), ('worst', 0.015386148069156514), ('rude', 0.015091544496828127), ('usairways', 0.01403604349627388), ('ever', 0.013401397508727687), ('loyal', 0.012480648164384784), ('fix', 0.011436125071156497), ('poor', 0.010690950344398207)]

# %%
model.visualize_topics()

# %%
model.visualize_barchart()

# %%
model = BERTopic(nr_topics=5)
topics, probabilities = model.fit_transform(train_data)

# %%
model.visualize_topics()

# %%
model.visualize_barchart()
